# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('cigs.csv')

# %%
data.head()
# Out:
#   Brand_Name flavor  CO  nic   tar  size filter pack menthol
# 0    Alpine     NaN  15  1.1  16.0   100      F   SP     yes
# 1    Alpine      Lt  12  0.8  10.0   100      F   SP     yes
# 2    Alpine     NaN  15  1.1  16.0  King      F   HP     yes
# 3    Alpine      Lt  11  0.7  10.0  King      F   HP     yes
# 4    Alpine     NaN  16  1.0  16.0  King      F   SP     yes

# %%
data.tail()
# Out:
#      Brand_Name    flavor  CO  nic   tar  size filter pack menthol
# 1120    Worth*         FF  17  0.8  14.0  King      F   SP     yes
# 1121    Worth*         Lt  13  0.7  10.0  King      F   SP      no
# 1122    Worth*         Lt  12  0.6   9.0  King      F   SP     yes
# 1123    Worth*   Ultra-Lt   6  0.3   4.0  King      F   SP      no
# 1124    Worth*        NaN  16  1.1  20.0  King     NF   SP      no

# %%
data.describe()
# Out:
#                 CO          nic          tar
# count  1125.000000  1125.000000  1125.000000
# mean     12.632000     0.756800    11.020889
# std       3.880287     0.275352     4.520393
# min       1.000000     0.100000     0.500000
# 25%      11.000000     0.600000     9.000000
# 50%      13.000000     0.800000    10.000000
# 75%      16.000000     0.900000    14.000000
# max      22.000000     2.000000    27.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1125 entries, 0 to 1124
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Brand_Name  1125 non-null   object
#  1   flavor      907 non-null    object
#  2   CO          1125 non-null   int64
#  3   nic         1125 non-null   float64
#  4   tar         1125 non-null   float64
#  5   size        1125 non-null   object
#  6   filter      1125 non-null   object
#  7   pack        1125 non-null   object
#  8   menthol     1125 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 79.2+ KB

# %%
data.describe(include = 'O')
# Out:
#        Brand_Name flavor  size filter  pack menthol
# count        1125    907  1125   1125  1125    1125
# unique        144     42     5      2     2       2
# top     Marlboro      Lt  King      F    SP      no
# freq           38    389   581   1063   844     752

# %%
from sklearn.preprocessing import LabelEncoder 
le=LabelEncoder()
data['Brand_Name']=le.fit_transform(data['Brand_Name'])
data['flavor']=le.fit_transform(data['flavor'])
data['size']=le.fit_transform(data['size'])
data['filter']=le.fit_transform(data['filter'])
data['pack']=le.fit_transform(data['pack'])
data['menthol']=le.fit_transform(data['menthol'])

# %%
data
# Out:
#       Brand_Name  flavor  CO  nic   tar  size  filter  pack  menthol
# 0              0      42  15  1.1  16.0     0       0     1        1
# 1              0      10  12  0.8  10.0     0       0     1        1
# 2              0      42  15  1.1  16.0     3       0     0        1
# 3              0      10  11  0.7  10.0     3       0     0        1
# 4              0      42  16  1.0  16.0     3       0     1        1
# ...          ...     ...  ..  ...   ...   ...     ...   ...      ...
# 1120         143       3  17  0.8  14.0     3       0     1        1
# 1121         143      10  13  0.7  10.0     3       0     1        0
# 1122         143      10  12  0.6   9.0     3       0     1        1
# 1123         143      37   6  0.3   4.0     3       0     1        0
# 1124         143      42  16  1.1  20.0     3       1     1        0
#
# [1125 rows x 9 columns]

# %%
data['flavor'].fillna(value=(data['flavor'].mode()),inplace=True)
data
# Out:
#       Brand_Name  flavor  CO  nic   tar  size  filter  pack  menthol
# 0              0      42  15  1.1  16.0     0       0     1        1
# 1              0      10  12  0.8  10.0     0       0     1        1
# 2              0      42  15  1.1  16.0     3       0     0        1
# 3              0      10  11  0.7  10.0     3       0     0        1
# 4              0      42  16  1.0  16.0     3       0     1        1
# ...          ...     ...  ..  ...   ...   ...     ...   ...      ...
# 1120         143       3  17  0.8  14.0     3       0     1        1
# 1121         143      10  13  0.7  10.0     3       0     1        0
# 1122         143      10  12  0.6   9.0     3       0     1        1
# 1123         143      37   6  0.3   4.0     3       0     1        0
# 1124         143      42  16  1.1  20.0     3       1     1        0
#
# [1125 rows x 9 columns]

# %%
sns.displot(x=data.Brand_Name,kde=True)
# Out:
# /Users/zebashaikh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.histplot(x=data. nic,kde=True)
# Out:
# <Axes: xlabel='nic', ylabel='Count'>

# %%
sns.histplot(x=data.tar ,kde=True)
# Out:
# <Axes: xlabel='tar', ylabel='Count'>

# %%
sns.histplot(x=data.pack  ,kde=True)
# Out:
# <Axes: xlabel='pack', ylabel='Count'>

# %%
sns.histplot(x=data.CO ,kde=True)
# Out:
# <Axes: xlabel='CO', ylabel='Count'>

# %%
data.head()
# Out:
#    Brand_Name  flavor  CO  nic   tar  size  filter  pack  menthol
# 0           0      42  15  1.1  16.0     0       0     1        1
# 1           0      10  12  0.8  10.0     0       0     1        1
# 2           0      42  15  1.1  16.0     3       0     0        1
# 3           0      10  11  0.7  10.0     3       0     0        1
# 4           0      42  16  1.0  16.0     3       0     1        1

# %%
sns.relplot(x='Brand_Name',y='nic',data=data)
# Out:
# /Users/zebashaikh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.plot(data.Brand_Name)
plt.plot(data.nic)

# %%
sns.relplot(x='flavor',y='CO',data=data)
# Out:
# /Users/zebashaikh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='pack',y='tar',data=data)
# Out:
# /Users/zebashaikh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(data)
# Out:
# /Users/zebashaikh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
data.isnull().sum()
# Out:
# Brand_Name    0
# flavor        0
# CO            0
# nic           0
# tar           0
# size          0
# filter        0
# pack          0
# menthol       0
# dtype: int64

# %%
sns.boxplot(x='flavor',data=data)
# Out:
# <Axes: xlabel='flavor'>

# %%
sns.boxplot(x='Brand_Name',data=data)
# Out:
# <Axes: xlabel='Brand_Name'>

# %%
sns.boxplot(x='CO',data=data)
# Out:
# <Axes: xlabel='CO'>

# %%
sns.boxplot(x='nic',data=data)
# Out:
# <Axes: xlabel='nic'>

# %%
data.head()
# Out:
#    Brand_Name  flavor  CO  nic   tar  size  filter  pack  menthol
# 0           0      42  15  1.1  16.0     0       0     1        1
# 1           0      10  12  0.8  10.0     0       0     1        1
# 2           0      42  15  1.1  16.0     3       0     0        1
# 3           0      10  11  0.7  10.0     3       0     0        1
# 4           0      42  16  1.0  16.0     3       0     1        1

# %%
sns.heatmap(data.drop('nic',axis=1).corr(),annot=True)
# Out:
# <Axes: >

# %%
data.corr()
# Out:
#             Brand_Name    flavor        CO       nic       tar      size  \
# Brand_Name    1.000000  0.068720 -0.012655  0.036736 -0.008241 -0.046763
# flavor        0.068720  1.000000 -0.374816 -0.043484 -0.115149  0.037445
# CO           -0.012655 -0.374816  1.000000  0.702216  0.826898  0.050196
# nic           0.036736 -0.043484  0.702216  1.000000  0.918102  0.106096
# tar          -0.008241 -0.115149  0.826898  0.918102  1.000000  0.203670
# size         -0.046763  0.037445  0.050196  0.106096  0.203670  1.000000
# filter       -0.015970  0.272745  0.189629  0.444092  0.546313  0.247764
# pack          0.001376 -0.106899  0.101434 -0.105488  0.000168 -0.073183
# menthol      -0.012776 -0.150610  0.071691  0.024790  0.017429 -0.108164
#
#               filter      pack   menthol
# Brand_Name -0.015970  0.001376 -0.012776
# flavor      0.272745 -0.106899 -0.150610
# CO          0.189629  0.101434  0.071691
# nic         0.444092 -0.105488  0.024790
# ...

# %%
data.head()
# Out:
#    Brand_Name  flavor  CO  nic   tar  size  filter  pack  menthol
# 0           0      42  15  1.1  16.0     0       0     1        1
# 1           0      10  12  0.8  10.0     0       0     1        1
# 2           0      42  15  1.1  16.0     3       0     0        1
# 3           0      10  11  0.7  10.0     3       0     0        1
# 4           0      42  16  1.0  16.0     3       0     1        1

# %%
#Step 1 Independent and dependent variable creation
X=data[['Brand_Name','flavor','CO','tar','size','filter','pack','menthol']] ## X variable contains all inputs
y=data.nic ## y is output

# %%
y
# Out:
# 0       15
# 1       12
# 2       15
# 3       11
# 4       16
#         ..
# 1120    17
# 1121    13
# 1122    12
# 1123     6
# 1124    16
# Name: CO, Length: 1125, dtype: int64

# %%
# Step 2 Traning and testing data creation
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
y_train
# Out:
# 408    15
# 640    17
# 231    12
# 489    15
# 659    17
#        ..
# 456    17
# 360     8
# 709    13
# 439    17
# 174    15
# Name: CO, Length: 900, dtype: int64

# %%
# Step 3 Creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() # object creation
LR.fit(X_train,y_train) # training of linear regression
y_predict=LR.predict(X_test)

# %%
y_test
# Out:
# 584    12
# 696    14
# 88     18
# 800    18
# 851    11
#        ..
# 722    10
# 866     8
# 89     17
# 322    12
# 980    14
# Name: CO, Length: 225, dtype: int64

# %%
y_predict
# Out:
# array([11.65535336, 12.45549127, 16.1509485 , 17.05762934, 10.20768263,
#         6.46578785, 14.61603648, 14.50093645, 16.22816948,  7.5048348 ,
#        12.20727445, 16.75782395, 12.77904407, 10.8799239 , 11.83599926,
#         7.36585248, 13.10095064, 12.36559049, 12.6017301 ,  9.67801286,
#        16.21269175, 14.38307045,  7.00851777, 16.36525597, 16.32192982,
#        16.78315452, 12.45942258, 12.45677271, 16.68658173, 11.10897737,
#         9.5825976 ,  9.75401181, 12.22310605, 12.52490413, 16.81323456,
#        14.30235988,  7.88131562, 14.21130157, 13.17250197,  9.56378385,
#        18.1181373 , 12.52490413, 10.1703272 , 15.85020382,  6.95943979,
#        12.30223995, 10.94006064, 16.34092775, 14.9524063 , 11.11689317,
#        16.50615725,  8.35942228, 13.504608  , 16.34726039,  5.8561448 ,
#        16.33359276, 17.58307763, 11.92824503, 12.7616293 , 14.39574299,
#        16.97688816, 16.03543359, 12.91671596, 15.56799961,  7.14337722,
# ...

# %%
X=data[['Brand_Name','flavor','CO','nic','size','filter','pack','menthol']] ## X variable contains all inputs
y=data.tar ## y is output

# %%
y
# Out:
# 0       16.0
# 1       10.0
# 2       16.0
# 3       10.0
# 4       16.0
#         ...
# 1120    14.0
# 1121    10.0
# 1122     9.0
# 1123     4.0
# 1124    20.0
# Name: tar, Length: 1125, dtype: float64

# %%
# Step 2 Traning and testing data creation
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
y_train
# Out:
# 408    23.0
# 640    14.0
# 231     8.0
# 489    16.0
# 659    13.0
#        ...
# 456    13.0
# 360     4.0
# 709    10.0
# 439    25.0
# 174    17.0
# Name: tar, Length: 900, dtype: float64

# %%
# Step 3 Creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() # object creation
LR.fit(X_train,y_train) # training of linear regression
y_predict=LR.predict(X_test)

# %%
y_test
# Out:
# 584    10.0
# 696    10.0
# 88     13.0
# 800    14.0
# 851     9.0
#        ...
# 722     9.0
# 866     4.0
# 89     13.0
# 322     9.0
# 980    15.0
# Name: tar, Length: 225, dtype: float64

# %%
y_predict
# Out:
# array([11.65535336, 12.45549127, 16.1509485 , 17.05762934, 10.20768263,
#         6.46578785, 14.61603648, 14.50093645, 16.22816948,  7.5048348 ,
#        12.20727445, 16.75782395, 12.77904407, 10.8799239 , 11.83599926,
#         7.36585248, 13.10095064, 12.36559049, 12.6017301 ,  9.67801286,
#        16.21269175, 14.38307045,  7.00851777, 16.36525597, 16.32192982,
#        16.78315452, 12.45942258, 12.45677271, 16.68658173, 11.10897737,
#         9.5825976 ,  9.75401181, 12.22310605, 12.52490413, 16.81323456,
#        14.30235988,  7.88131562, 14.21130157, 13.17250197,  9.56378385,
#        18.1181373 , 12.52490413, 10.1703272 , 15.85020382,  6.95943979,
#        12.30223995, 10.94006064, 16.34092775, 14.9524063 , 11.11689317,
#        16.50615725,  8.35942228, 13.504608  , 16.34726039,  5.8561448 ,
#        16.33359276, 17.58307763, 11.92824503, 12.7616293 , 14.39574299,
#        16.97688816, 16.03543359, 12.91671596, 15.56799961,  7.14337722,
# ...

# %%
X=data[['Brand_Name','flavor','tar','nic','size','filter','pack','menthol']] ## X variable contains all inputs
y=data.CO ## y is output

# %%
y
# Out:
# 0       15
# 1       12
# 2       15
# 3       11
# 4       16
#         ..
# 1120    17
# 1121    13
# 1122    12
# 1123     6
# 1124    16
# Name: CO, Length: 1125, dtype: int64

# %%
# Step 2 Traning and testing data creation
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
y_train
# Out:
# 408    23.0
# 640    14.0
# 231     8.0
# 489    16.0
# 659    13.0
#        ...
# 456    13.0
# 360     4.0
# 709    10.0
# 439    25.0
# 174    17.0
# Name: tar, Length: 900, dtype: float64

# %%
# Step 3 Creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() # object creation
LR.fit(X_train,y_train) # training of linear regression
y_predict=LR.predict(X_test)

# %%
y_test
# Out:
# 584    10.0
# 696    10.0
# 88     13.0
# 800    14.0
# 851     9.0
#        ...
# 722     9.0
# 866     4.0
# 89     13.0
# 322     9.0
# 980    15.0
# Name: tar, Length: 225, dtype: float64

# %%
y_predict
# Out:
# array([10.19676918, 11.32189935, 13.41220512, 13.19324386,  9.85529138,
#         4.03068206, 16.61565904, 14.81908438, 14.01633591,  6.43807562,
#        10.76955154, 12.90695944,  9.64578008,  8.81509409, 15.24611383,
#         6.37775188, 10.9802692 , 10.55151775,  9.88997793, 10.82690219,
#        13.32717194, 14.47013701,  6.11728124, 13.72438102, 13.17672862,
#        12.87207404, 12.42596456, 13.77714894, 13.00507465,  8.75965183,
#         9.43706037,  9.36681876, 10.74774816, 11.02785398, 12.83064762,
#        11.16784043,  4.09603847, 13.36757522, 13.32635431,  9.48270412,
#        13.57486517, 11.02785398, 10.44639073, 13.13831779,  5.70244706,
#        11.57972512, 11.75515717, 13.15056456, 15.98378496,  9.2311748 ,
#        13.53033095,  6.26345985, 10.23943202, 13.14184321,  4.18338435,
#        13.76798778, 15.46151971,  9.55527003,  9.6697638 , 13.57969176,
#        13.3044411 , 12.88321825, 10.53482012, 14.09482148,  4.37001598,
# ...

# %%
# Step 4 Model Evalution

from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
r2score=r2_score(y_test,y_predict)

# %%
r2score
# Out:
# 0.9631309437381439

# %%
X_test.shape
# Out:
# (225, 8)

# %%
## calculation of adjusted r2 score
adjusted_r2 = 1-(1-0.90)*(40-3)/(40-3-1)
adjusted_r2
# Out:
# 0.8972222222222223

# %%
import math
print(mean_squared_error(y_test,y_predict))
print(math.sqrt(mean_squared_error(y_test,y_predict))) # root mean squared error
# Out:
# 0.6072014944853832
# 0.7792313485001634

# %%
print(mean_absolute_error(y_test,y_predict))
# Out:
# 0.6109191707019082
